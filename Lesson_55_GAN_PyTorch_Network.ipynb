# %% [markdown]
# **Завдання**
# ### Використовуючи бібліотеку **PyTorch**, створіть генеративно-змагагальну функцію (GAN) для генерації зображень цифр **MNIST**.

# %%
# Required libraries.
import torch
from torch import nn
from torch.utils.data import DataLoader
import matplotlib.pyplot as plt
import torchvision
import torchvision.transforms as transforms

import warnings
warnings.simplefilter('ignore')

# %%
# Setting up the random generator seed.
torch.manual_seed(111)

# %%
# For using cuba device.
device = ''
if torch.cuda.is_available():
    device = torch.device('cuda')
else:
    device = torch.device('cpu')

# %% [markdown]
# ## **Preparing and downloading a dataset**

# %%
# Preparing a data:
# Transforms.ToTensor() - converts the data to a PyTorch tensor.
# Transforms.Normalize() - converts the range of the tensor coefficients.
transform = transforms.Compose(
    [transforms.ToTensor(), transforms.Normalize((0.5,), (0.5,))]
)

# %%
# Downloading the data.
train_set = torchvision.datasets.MNIST(
    root="E:\Python DEVELOPER\StartUpAcademy\projects\lesson_55\DATA",
     train=True, download=True, transform=transform
)

# Batches of 32 samples.
batch_size = 32

# Creating a dataloader.
train_loader = torch.utils.data.DataLoader(
    train_set, batch_size=batch_size, shuffle=True)

# %%
# Visualisation a real samples of the data.
real_samples, mnist_labels = next(iter(train_loader))
for i in range(16):
    ax = plt.subplot(5, 4, i + 1)
    plt.imshow(real_samples[i].reshape(28, 28))
    plt.xticks([])
    plt.yticks([])

# %% [markdown]
# ## **The Generator and the Discriminator implementation**

# %%
# Making the Generator model with the ReLU activation function.
class Generator(nn.Module):

    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(100, 256),
            nn.ReLU(),
            nn.Linear(256, 512),
            nn.ReLU(),
            nn.Linear(512, 1024),
            nn.ReLU(),
            nn.Linear(1024, 784),
            nn.Tanh(), #  The output layer is activated by hyperbolic tangent function. 
        )

    def forward(self, x):
        output = self.model(x)
        output = output.view(x.size(0), 1, 28, 28)
        return output


# Creating an instance of the Generator and running it.
generator = Generator().to(device=device)

# %%
# # Making the Discriminator model with the ReLU activation function.
class Discriminator(nn.Module):
    def __init__(self):
        super().__init__()
        self.model = nn.Sequential(
            nn.Linear(784, 1024),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(1024, 512),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(512, 256),
            nn.ReLU(),
            nn.Dropout(0.3),
            nn.Linear(256, 1),
            nn.Sigmoid(),
        )


    def forward(self, x):
        x = x.view(x.size(0), 784)
        output = self.model(x)
        return output


# Creating an instance of the Discriminator and running it.
discriminator = Discriminator().to(device=device)

# %% [markdown]
# ## **Training the Models**

# %%
# Identification of the parameters of the model.
lr = 0.0001
num_epochs = 50
loss_function = nn.BCELoss() # Binary Crossentropy Loss function.

# Choosing the Adam optimizers for finding the best possible set of parameters.
# To minimize the loss between the predictions and the ground truth.
optimizer_discriminator = torch.optim.Adam(discriminator.parameters(), lr=lr)
optimizer_generator = torch.optim.Adam(generator.parameters(), lr=lr)

# %% [markdown]
# ### The training loop of the model:

# %%
# Creating the loop.
for epoch in range(num_epochs):
    for n, (real_samples, mnist_labels) in enumerate(train_loader):


        # Data for training the discriminator.
        real_samples = real_samples.to(device=device)
        real_samples_labels = torch.ones((batch_size, 1)).to(device=device)

        latent_space_samples = torch.randn((batch_size, 100)).to(device=device)

        generated_samples = generator(latent_space_samples)
        generated_samples_labels = torch.zeros((batch_size, 1)).to(device=device)

        all_samples = torch.cat((real_samples, generated_samples))
        all_samples_labels = torch.cat(
            (real_samples_labels, generated_samples_labels)
        )

        # Training the discriminator.
        discriminator.zero_grad()
        output_discriminator = discriminator(all_samples)
        loss_discriminator = loss_function(
            output_discriminator, all_samples_labels
        )

        loss_discriminator.backward()
        optimizer_discriminator.step()

        # Data for training the generator.
        latent_space_samples = torch.randn((batch_size, 100)).to(device=device)

        # Training the generator.
        generator.zero_grad()
        generated_samples = generator(latent_space_samples)
        output_discriminator_generated = discriminator(generated_samples)
        loss_generator = loss_function(
            output_discriminator_generated, real_samples_labels
        )

        loss_generator.backward()
        optimizer_generator.step()


        # The loss of the Generator and the Discriminator.
        if n == batch_size - 1:            
            print(f'Epoch: {epoch} | Loss the Generator: {loss_generator:.3f} | Loss the Discriminator: {loss_discriminator:.3f}')
# Out:
# Epoch: 0 | Loss the Generator: 0.552 | Loss the Discriminator: 0.541
# Epoch: 1 | Loss the Generator: 4.836 | Loss the Discriminator: 0.047
# Epoch: 2 | Loss the Generator: 7.540 | Loss the Discriminator: 0.079
# Epoch: 3 | Loss the Generator: 4.698 | Loss the Discriminator: 0.010
# Epoch: 4 | Loss the Generator: 5.062 | Loss the Discriminator: 0.067
# Epoch: 5 | Loss the Generator: 4.385 | Loss the Discriminator: 0.084
# Epoch: 6 | Loss the Generator: 4.604 | Loss the Discriminator: 0.153
# Epoch: 7 | Loss the Generator: 4.019 | Loss the Discriminator: 0.120
# Epoch: 8 | Loss the Generator: 3.169 | Loss the Discriminator: 0.168
# Epoch: 9 | Loss the Generator: 2.223 | Loss the Discriminator: 0.175
# Epoch: 10 | Loss the Generator: 1.399 | Loss the Discriminator: 0.281
# Epoch: 11 | Loss the Generator: 1.753 | Loss the Discriminator: 0.487
# Epoch: 12 | Loss the Generator: 1.804 | Loss the Discriminator: 0.465
# Epoch: 13 | Loss the Generator: 1.212 | Loss the Discriminator: 0.412
# Epoch: 14 | Loss the Generator: 1.551 | Loss the Discriminator: 0.422
# Epoch: 15 | Loss the Generator: 1.363 | Loss the Discriminator: 0.450
# Epoch: 16 | Loss the Generator: 1.359 | Loss the Discriminator: 0.561
# Epoch: 17 | Loss the Generator: 1.494 | Loss the Discriminator: 0.594
# Epoch: 18 | Loss the Generator: 1.466 | Loss the Discriminator: 0.464
# Epoch: 19 | Loss the Generator: 1.267 | Loss the Discriminator: 0.601
# Epoch: 20 | Loss the Generator: 1.071 | Loss the Discriminator: 0.551
# Epoch: 21 | Loss the Generator: 1.172 | Loss the Discriminator: 0.572
# Epoch: 22 | Loss the Generator: 1.502 | Loss the Discriminator: 0.589
# Epoch: 23 | Loss the Generator: 1.258 | Loss the Discriminator: 0.583
# Epoch: 24 | Loss the Generator: 1.243 | Loss the Discriminator: 0.529
# Epoch: 25 | Loss the Generator: 1.028 | Loss the Discriminator: 0.490
# Epoch: 26 | Loss the Generator: 1.189 | Loss the Discriminator: 0.623
# Epoch: 27 | Loss the Generator: 1.065 | Loss the Discriminator: 0.571
# Epoch: 28 | Loss the Generator: 1.005 | Loss the Discriminator: 0.513
# Epoch: 29 | Loss the Generator: 1.041 | Loss the Discriminator: 0.548
# Epoch: 30 | Loss the Generator: 1.091 | Loss the Discriminator: 0.558
# Epoch: 31 | Loss the Generator: 1.090 | Loss the Discriminator: 0.520
# Epoch: 32 | Loss the Generator: 1.189 | Loss the Discriminator: 0.598
# Epoch: 33 | Loss the Generator: 1.211 | Loss the Discriminator: 0.594
# Epoch: 34 | Loss the Generator: 0.979 | Loss the Discriminator: 0.599
# Epoch: 35 | Loss the Generator: 0.951 | Loss the Discriminator: 0.539
# Epoch: 36 | Loss the Generator: 0.960 | Loss the Discriminator: 0.585
# Epoch: 37 | Loss the Generator: 1.188 | Loss the Discriminator: 0.590
# Epoch: 38 | Loss the Generator: 1.198 | Loss the Discriminator: 0.446
# Epoch: 39 | Loss the Generator: 0.970 | Loss the Discriminator: 0.571
# Epoch: 40 | Loss the Generator: 1.187 | Loss the Discriminator: 0.588
# Epoch: 41 | Loss the Generator: 0.931 | Loss the Discriminator: 0.617
# Epoch: 42 | Loss the Generator: 1.130 | Loss the Discriminator: 0.663
# Epoch: 43 | Loss the Generator: 0.994 | Loss the Discriminator: 0.597
# Epoch: 44 | Loss the Generator: 1.041 | Loss the Discriminator: 0.671
# Epoch: 45 | Loss the Generator: 1.236 | Loss the Discriminator: 0.602
# Epoch: 46 | Loss the Generator: 1.103 | Loss the Discriminator: 0.596
# Epoch: 47 | Loss the Generator: 1.099 | Loss the Discriminator: 0.585
# Epoch: 48 | Loss the Generator: 1.071 | Loss the Discriminator: 0.609
# Epoch: 49 | Loss the Generator: 1.274 | Loss the Discriminator: 0.567

# %% [markdown]
# ## **The result generated by the GAN Model after 50 epochs**

# %%
# Choosing a random samples from the model for feeding to the generator.
latent_space_samples = torch.randn(batch_size, 100).to(device=device)
generated_samples = generator(latent_space_samples)

# %%
# Visualization of the generated result.
generated_samples = generated_samples.cpu().detach()
for i in range(16):
    ax = plt.subplot(5, 4, i + 1)
    plt.imshow(generated_samples[i].reshape(28, 28))
    plt.xticks([])
    plt.yticks([])
